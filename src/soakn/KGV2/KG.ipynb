# %%
import pandas as pd, rdflib as rdf, yaml, pathlib, datetime

# %%
from urllib.parse import quote_plus

BASE = "https://example.org/retail/"

def uri(entity_type: str, key) -> str:
    """
    Mint a deterministic URI like
    https://example.org/retail/product/123 or
    https://example.org/retail/household/H001

    entity_type : short slug ('product', 'household', 'store', 'txn', …)
    key         : primary-key value from the CSV (str or int)
    """
    return f"{BASE}{entity_type}/{quote_plus(str(key))}"

from neo4j import GraphDatabase, basic_auth
import glob, pathlib, time

URI, AUTH = "bolt://localhost:7687", basic_auth("neo4j", "sebastienM19")
driver = GraphDatabase.driver(URI, auth=AUTH)

# %%
CFG = yaml.safe_load(open("config.yaml"))
g = rdf.Graph()
NS = {pfx: rdf.Namespace(uri) for pfx, uri in CFG["prefixes"].items()}
for pfx, ns in NS.items():
    g.bind(pfx, ns)
    
def new_graph():
    g = rdf.Graph()
    for pfx, uri in CFG["prefixes"].items():
        g.bind(pfx, rdf.Namespace(uri))
    return g

def day_time_to_iso(day, trans_time):
    # DAY is offset in dataset (1-711); Jan-01-2017 baseline
    date = datetime.date(2017, 1, 1) + datetime.timedelta(int(day))
    hh, mm = divmod(int(trans_time), 100)
    return datetime.datetime.combine(date, datetime.time(hh, mm)).isoformat()

chunksize = 1000
for chunk in pd.read_csv("../../../data/transaction_data.csv", chunksize=chunksize):
    g = new_graph()
    for row in chunk.itertuples():
        txn = rdf.URIRef(uri("txn", row.BASKET_ID))
        g.add((txn, rdf.RDF.type, NS["rio"].Transaction))
        g.add((txn, NS["rio"].hasCustomer, rdf.URIRef(uri("household", row.household_key))))
        g.add((txn, NS["time"].inXSDDateTime, rdf.Literal(day_time_to_iso(row.DAY, row.TRANS_TIME), datatype=rdf.XSD.dateTime)))
        g.add((txn, NS["rio"].occurredAt, rdf.URIRef(uri("store", row.STORE_ID))))
        # line item
        line = rdf.BNode()
        g.add((line, rdf.RDF.type, NS["rio"].TransactionLine))
        g.add((line, NS["rio"].lineProduct, rdf.URIRef(uri("product", row.PRODUCT_ID))))
        g.add((txn, NS["rio"].containsLine, line))
        g.add((line, NS["rio"].lineProduct, rdf.URIRef(uri("product", row.PRODUCT_ID))))
        g.add((line, NS["rio"].quantity, rdf.Literal(int(row.QUANTITY))))
        g.add((line, NS["rio"].lineTotal, rdf.Literal(float(row.SALES_VALUE))))
    ttl_file = pathlib.Path("export") / f"transactions_{chunk.index.start}.ttl"
    g.serialize(destination=ttl_file, format="turtle")
    g.remove((None, None, None))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 37
#      35     g.add((line, NS["rio"].lineTotal, rdf.Literal(float(row.SALES_VALUE))))
#      36 ttl_file = pathlib.Path("export") / f"transactions_{chunk.index.start}.ttl"
# ---> 37 g.serialize(destination=ttl_file, format="turtle")
#      38 g.remove((None, None, None))
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/graph.py:1408, in Graph.serialize(self, destination, format, base, encoding, **args)
#    1406             os_path = location
#    1407     with open(os_path, "wb") as stream:
# -> 1408         serializer.serialize(stream, base=base, encoding=encoding, **args)
#    1409 return self
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/plugins/serializers/turtle.py:244, in TurtleSerializer.serialize(self, stream, base, encoding, spacious, **kwargs)
#     241 if spacious is not None:
#     242     self._spacious = spacious
# --> 244 self.preprocess()
#     245 subjects_list = self.orderSubjects()
#     247 self.startDocument()
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/plugins/serializers/turtle.py:94, in RecursiveSerializer.preprocess(self)
#      93 def preprocess(self) -> None:
# ---> 94     for triple in self.store.triples((None, None, None)):
#      95         self.preprocessTriple(triple)
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/graph.py:638, in Graph.triples(self, triple)
#     636         yield _s, p, _o
#     637 else:
# --> 638     for (_s, _p, _o), cg in self.__store.triples((s, p, o), context=self):
#     639         yield _s, _p, _o
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/plugins/stores/memory.py:436, in Memory.triples(self, triple_pattern, context)
#     434         return
#     435     for triple in self.__contextTriples[req_ctx].copy():
# --> 436         yield triple, self.__contexts(triple)
#     438 # optimize "triple in graph" case (all parts given)
#     439 elif subject is not None and predicate is not None and object_ is not None:
#     440     # type error: Incompatible types in assignment (expression has type "Tuple[Optional[IdentifiedNode], Optional[IdentifiedNode], Optional[Identifier]]", variable has type "Tuple[IdentifiedNode, IdentifiedNode, Identifier]")
#     441     # NOTE on type error: at this point, all elements of triple_pattern
#     442     # is not None, so it has the same type as triple
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/plugins/stores/memory.py:714, in Memory.__contexts(self, triple)
#     709 """return a generator for all the non-quoted contexts
#     710 (dereferenced) the encoded triple appears in"""
#     711 # type error: Argument 2 to "get" of "Mapping" has incompatible type "str"; expected "Optional[Graph]"
#     712 return (
#     713     self.__context_obj_map.get(ctx_str, ctx_str)  # type: ignore[arg-type]
# --> 714     for ctx_str in self.__get_context_for_triple(triple, skipQuoted=True)
#     715     if ctx_str is not None
#     716 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/soakn-N2LZEInT-py3.13/lib/python3.13/site-packages/rdflib/plugins/stores/memory.py:650, in Memory.__get_context_for_triple(self, triple, skipQuoted)
#     647     if triple_context == self.__defaultContexts:
#     648         del self.__tripleContexts[triple]
# --> 650 def __get_context_for_triple(
#     651     self, triple: _TripleType, skipQuoted: bool = False  # noqa: N803
#     652 ) -> Collection[Optional[str]]:
#     653     """return a list of contexts (str) for the triple, skipping
#     654     quoted contexts if skipQuoted==True"""
#     656     ctxs = self.__tripleContexts.get(triple, self.__defaultContexts)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv("../../../data/product.csv", dtype=str).fillna("")
for row in df.itertuples(index=False):
    prd = rdf.URIRef(uri("product", row.PRODUCT_ID))
    g.add((prd, rdf.RDF.type,           NS["gr"].ProductOrServiceModel))
    g.add((prd, NS["gr"].name,          rdf.Literal(row.SUB_COMMODITY_DESC)))
    g.add((prd, NS["schema"].brand,     rdf.Literal(row.BRAND)))

    # manufacturer as an Organization node
    if row.MANUFACTURER:
        m_uri = rdf.URIRef(uri("manufacturer", row.MANUFACTURER))
        g.add((m_uri, rdf.RDF.type,      NS["schema"].Organization))
        g.add((prd,  NS["schema"].manufacturer, m_uri))

    # size-of-product literal (keep text, e.g. "12 OZ")
    if row.CURR_SIZE_OF_PRODUCT:
        g.add((prd, NS["schema"].packageQuantity,
               rdf.Literal(row.CURR_SIZE_OF_PRODUCT)))

    # taxonomy: Department ⭢ Commodity ⭢ Sub-commodity
    dept_uri      = rdf.URIRef(uri("dept", row.DEPARTMENT))
    commod_uri    = rdf.URIRef(uri("commodity", row.COMMODITY_DESC))
    subcommod_uri = rdf.URIRef(uri("subcomm", row.SUB_COMMODITY_DESC))

    g.add((dept_uri,      rdf.RDF.type, NS["skos"].Concept))
    g.add((commod_uri,    rdf.RDF.type, NS["skos"].Concept))
    g.add((subcommod_uri, rdf.RDF.type, NS["skos"].Concept))

    g.add((commod_uri,    NS["skos"].broader, dept_uri))
    g.add((subcommod_uri, NS["skos"].broader, commod_uri))
    g.add((prd,           NS["skos"].broader, subcommod_uri))

# ---  write -------------------------------------------------------------------
export = pathlib.Path("export")
export.mkdir(exist_ok=True)
g.serialize(destination=export / "products.ttl", format="turtle")
print("✓ products.ttl written (", len(df), "products )")
# Out:
# ✓ products.ttl written ( 92353 products )

# %%
df = pd.read_csv("../../../data/hh_demographic.csv", dtype=str).fillna("")
def parse_household_size(size_text: str) -> int | None:
    """Convert '1-2' → 2, '3' → 3, '5+' → 5 ."""
    if not size_text:
        return None
    if "-" in size_text:
        return int(size_text.split("-")[-1])
    if size_text.endswith("+"):
        return int(size_text[:-1])
    return int(size_text)

for row in df.itertuples(index=False):
    hh = rdf.URIRef(uri("household", row.household_key))
    g.add((hh, rdf.RDF.type,         NS["foaf"].Group))

    # simple literals as RUPO predicates
    if row.AGE_DESC:
        g.add((hh, NS["rupo"].ageBand, rdf.Literal(row.AGE_DESC)))
    if row.INCOME_DESC:
        g.add((hh, NS["rupo"].incomeBand, rdf.Literal(row.INCOME_DESC)))
    if row.HOMEOWNER_DESC:
        g.add((hh, NS["rupo"].homeownerStatus, rdf.Literal(row.HOMEOWNER_DESC)))
    if row.MARITAL_STATUS_CODE:
        g.add((hh, NS["rupo"].maritalStatus, rdf.Literal(row.MARITAL_STATUS_CODE)))

    # numeric size (optional)
    size_val = parse_household_size(row.HOUSEHOLD_SIZE_DESC)
    if size_val:
        g.add((hh, NS["rupo"].householdSize, rdf.Literal(size_val)))

    if row.KID_CATEGORY_DESC:
        g.add((hh, NS["rupo"].kidCategory, rdf.Literal(row.KID_CATEGORY_DESC)))

# ---  write -------------------------------------------------------------------
export = pathlib.Path("export")
export.mkdir(exist_ok=True)
g.serialize(destination=export / "households.ttl", format="turtle")
print("✓ households.ttl written (", len(df), "households )")
# Out:
# ✓ households.ttl written ( 801 households )

# %%
def register_prefixes():
    with driver.session() as session:
        for prefix, uri in CFG["prefixes"].items():
            session.run("""
                CALL n10s.nsprefixes.add($prefix, $namespace)
            """, prefix=prefix, namespace=uri)

register_prefixes()
print("✓ Registered RDF namespace prefixes.")

# %%
def import_ttl(path):
    with driver.session() as s:
        s.run("""
            CALL n10s.rdf.import.fetch($url,'Turtle',{ handleVocabUris: "SHORTEN" })
        """, url=f"file:///{path}")

for ttl in glob.glob("export/*.ttl"):
    print("loading", pathlib.Path(ttl).name)
    import_ttl(ttl)
    time.sleep(0.1)
# Out:
# loading transactions_250000.ttl
# loading transactions_233000.ttl
# loading transactions_184000.ttl
# loading transactions_242000.ttl
# loading transactions_188000.ttl
# loading transactions_196000.ttl
# loading transactions_221000.ttl
# loading transactions_274000.ttl
# loading transactions_81000.ttl
# loading transactions_209000.ttl
# loading transactions_217000.ttl
# loading transactions_266000.ttl
# loading transactions_93000.ttl
# loading transactions_278000.ttl
# loading transactions_205000.ttl
# loading transactions_27000.ttl
# loading transactions_165000.ttl
# loading transactions_118000.ttl
# loading transactions_39000.ttl
# loading transactions_106000.ttl
# loading transactions_44000.ttl
# loading transactions_35000.ttl
# loading transactions_177000.ttl
# loading transactions_48000.ttl
# loading transactions_169000.ttl
# loading transactions_114000.ttl
# loading transactions_56000.ttl
# loading transactions_141000.ttl
# loading transactions_60000.ttl
# loading transactions_122000.ttl
# loading transactions_153000.ttl
# loading transactions_11000.ttl
# loading transactions_1000.ttl
# loading transactions_72000.ttl
# loading transactions_130000.ttl
# loading transactions_29000.ttl
# loading transactions_54000.ttl
# loading transactions_116000.ttl
# loading transactions_175000.ttl
# loading transactions_37000.ttl
# loading transactions_108000.ttl
# loading transactions_179000.ttl
# loading transactions_46000.ttl
# loading transactions_104000.ttl
# loading transactions_167000.ttl
# loading transactions_25000.ttl
# loading transactions_58000.ttl
# loading transactions_285000.ttl
# loading transactions_132000.ttl
# loading transactions_70000.ttl
# loading transactions_13000.ttl
# loading transactions_151000.ttl
# loading transactions_3000.ttl
# loading transactions_120000.ttl
# loading transactions_62000.ttl
# loading transactions_143000.ttl
# loading transactions_194000.ttl
# loading transactions_223000.ttl
# loading transactions_240000.ttl
# loading transactions_231000.ttl
# loading transactions_186000.ttl
# loading transactions_252000.ttl
# loading transactions_198000.ttl
# loading transactions_207000.ttl
# loading transactions_91000.ttl
# loading transactions_264000.ttl
# loading transactions_219000.ttl
# loading transactions_268000.ttl
# loading transactions_215000.ttl
# loading transactions_83000.ttl
# loading transactions_276000.ttl
# loading transactions_124000.ttl
# loading transactions_66000.ttl
# loading transactions_159000.ttl
# loading transactions_78000.ttl
# loading transactions_147000.ttl
# loading transactions_281000.ttl
# loading transactions_136000.ttl
# loading transactions_74000.ttl
# loading transactions_7000.ttl
# loading transactions_128000.ttl
# loading transactions_17000.ttl
# loading transactions_155000.ttl
# loading transactions_42000.ttl
# loading transactions_100000.ttl
# loading transactions_163000.ttl
# loading transactions_21000.ttl
# loading transactions_50000.ttl
# loading transactions_112000.ttl
# loading transactions_171000.ttl
# loading transactions_33000.ttl
# loading transactions_211000.ttl
# loading transactions_99000.ttl
# loading transactions_87000.ttl
# loading transactions_272000.ttl
# loading transactions_203000.ttl
# loading transactions_95000.ttl
# loading transactions_260000.ttl
# loading transactions_235000.ttl
# loading transactions_182000.ttl
# loading transactions_248000.ttl
# loading transactions_256000.ttl
# loading transactions_190000.ttl
# loading transactions_227000.ttl
# loading transactions_239000.ttl
# loading transactions_244000.ttl
# loading transactions_262000.ttl
# loading transactions_97000.ttl
# loading transactions_201000.ttl
# loading transactions_89000.ttl
# loading transactions_270000.ttl
# loading transactions_85000.ttl
# loading transactions_213000.ttl
# loading transactions_246000.ttl
# loading transactions_192000.ttl
# loading transactions_225000.ttl
# loading transactions_258000.ttl
# loading transactions_229000.ttl
# loading transactions_254000.ttl
# loading transactions_237000.ttl
# loading transactions_180000.ttl
# loading transactions_5000.ttl
# loading transactions_68000.ttl
# loading transactions_157000.ttl
# loading transactions_15000.ttl
# loading transactions_76000.ttl
# loading transactions_283000.ttl
# loading transactions_134000.ttl
# loading transactions_149000.ttl
# loading transactions_138000.ttl
# loading transactions_145000.ttl
# loading transactions_64000.ttl
# loading transactions_126000.ttl
# loading transactions_9000.ttl
# loading transactions_19000.ttl
# loading transactions_31000.ttl
# loading transactions_173000.ttl
# loading transactions_110000.ttl
# loading transactions_52000.ttl
# loading transactions_23000.ttl
# loading transactions_161000.ttl
# loading transactions_102000.ttl
# loading transactions_40000.ttl
# loading transactions_61000.ttl
# loading transactions_123000.ttl
# loading transactions_140000.ttl
# loading transactions_73000.ttl
# loading transactions_131000.ttl
# loading transactions_286000.ttl
# loading transactions_152000.ttl
# loading transactions_10000.ttl
# loading transactions_107000.ttl
# loading transactions_45000.ttl
# loading transactions_38000.ttl
# loading transactions_119000.ttl
# loading transactions_26000.ttl
# loading transactions_164000.ttl
# loading transactions_115000.ttl
# loading transactions_57000.ttl
# loading transactions_168000.ttl
# loading transactions_49000.ttl
# loading transactions_34000.ttl
# loading transactions_176000.ttl
# loading transactions_216000.ttl
# loading products.ttl
# loading transactions_208000.ttl
# loading transactions_275000.ttl
# loading transactions_80000.ttl
# loading transactions_204000.ttl
# loading transactions_279000.ttl
# loading transactions_267000.ttl
# loading transactions_92000.ttl
# loading transactions_185000.ttl
# loading transactions_232000.ttl
# loading transactions_251000.ttl
# loading transactions_220000.ttl
# loading transactions_197000.ttl
# loading transactions_189000.ttl
# loading transactions_243000.ttl
# loading transactions_218000.ttl
# loading transactions_90000.ttl
# loading transactions_265000.ttl
# loading transactions_206000.ttl
# loading transactions_82000.ttl
# loading transactions_277000.ttl
# loading transactions_214000.ttl
# loading transactions_269000.ttl
# loading transactions_241000.ttl
# loading transactions_222000.ttl
# loading transactions_195000.ttl
# loading transactions_199000.ttl
# loading transactions_253000.ttl
# loading transactions_187000.ttl
# loading transactions_230000.ttl
# loading transactions_2000.ttl
# loading transactions_12000.ttl
# loading transactions_150000.ttl
# loading transactions_133000.ttl
# loading transactions_284000.ttl
# loading transactions_71000.ttl
# loading transactions_142000.ttl
# loading transactions_121000.ttl
# loading transactions_63000.ttl
# loading transactions_109000.ttl
# loading transactions_174000.ttl
# loading transactions_36000.ttl
# loading transactions_55000.ttl
# loading transactions_117000.ttl
# loading transactions_28000.ttl
# loading transactions_59000.ttl
# loading transactions_166000.ttl
# loading transactions_24000.ttl
# loading transactions_47000.ttl
# loading transactions_105000.ttl
# loading transactions_178000.ttl
# loading transactions_257000.ttl
# loading transactions_249000.ttl
# loading transactions_183000.ttl
# loading transactions_234000.ttl
# loading transactions_245000.ttl
# loading transactions_238000.ttl
# loading transactions_226000.ttl
# loading transactions_191000.ttl
# loading transactions_86000.ttl
# loading transactions_273000.ttl
# loading transactions_98000.ttl
# loading transactions_210000.ttl
# loading transactions_94000.ttl
# loading transactions_261000.ttl
# loading transactions_202000.ttl
# loading transactions_162000.ttl
# loading transactions_20000.ttl
# loading households.ttl
# loading transactions_43000.ttl
# loading transactions_101000.ttl
# loading transactions_170000.ttl
# loading transactions_32000.ttl
# loading transactions_51000.ttl
# loading transactions_113000.ttl
# loading transactions_146000.ttl
# loading transactions_79000.ttl
# loading transactions_158000.ttl
# loading transactions_125000.ttl
# loading transactions_67000.ttl
# loading transactions_16000.ttl
# loading transactions_154000.ttl
# loading transactions_129000.ttl
# loading transactions_6000.ttl
# loading transactions_137000.ttl
# loading transactions_280000.ttl
# loading transactions_75000.ttl
# loading transactions_111000.ttl
# loading transactions_53000.ttl
# loading transactions_30000.ttl
# loading transactions_172000.ttl
# loading transactions_103000.ttl
# loading transactions_41000.ttl
# loading transactions_0.ttl
# loading transactions_22000.ttl
# loading transactions_160000.ttl
# loading transactions_148000.ttl
# loading transactions_77000.ttl
# loading transactions_135000.ttl
# loading transactions_282000.ttl
# loading transactions_156000.ttl
# loading transactions_14000.ttl
# loading transactions_4000.ttl
# loading transactions_69000.ttl
# loading transactions_18000.ttl
# loading transactions_65000.ttl
# loading transactions_8000.ttl
# loading transactions_127000.ttl
# loading transactions_144000.ttl
# loading transactions_139000.ttl
# loading transactions_259000.ttl
# loading transactions_224000.ttl
# loading transactions_193000.ttl
# loading transactions_247000.ttl
# loading transactions_181000.ttl
# loading transactions_236000.ttl
# loading transactions_255000.ttl
# loading transactions_228000.ttl
# loading transactions_88000.ttl
# loading transactions_200000.ttl
# loading transactions_263000.ttl
# loading transactions_96000.ttl
# loading transactions_212000.ttl
# loading transactions_271000.ttl
# loading transactions_84000.ttl

# %%
def import_ttl(filename: pathlib.Path):
    url = f"file:///import/{filename.name}"
    with driver.session() as s:
        s.run("""
            CALL n10s.rdf.import.fetch(
              $url, 'Turtle', { handleVocabUris: "SHORTEN" })
        """, url=url)

# %%
export_dir = pathlib.Path("export")

# %%
def import_schema(path):
    with driver.session() as session:
        session.run("""
            CALL n10s.rdf.import.fetch($url, 'Turtle', { handleVocabUris: "SHORTEN", typesToLabels: true })
        """, url=f"file:///{path}")

import_schema("export/schema.ttl")
print("✓ Imported schema.ttl into Neo4j")
# Out:
# loading households.ttl
# loading products.ttl
# loading transactions_0.ttl
# loading transactions_1000.ttl
# loading transactions_10000.ttl
# loading transactions_100000.ttl
# loading transactions_101000.ttl
# loading transactions_102000.ttl
# loading transactions_103000.ttl
# loading transactions_104000.ttl
# loading transactions_105000.ttl
# loading transactions_106000.ttl
# loading transactions_107000.ttl
# loading transactions_108000.ttl
# loading transactions_109000.ttl
# loading transactions_11000.ttl
# loading transactions_110000.ttl
# loading transactions_111000.ttl
# loading transactions_112000.ttl
# loading transactions_113000.ttl
# loading transactions_114000.ttl
# loading transactions_115000.ttl
# loading transactions_116000.ttl
# loading transactions_117000.ttl
# loading transactions_118000.ttl
# loading transactions_119000.ttl
# loading transactions_12000.ttl
# loading transactions_120000.ttl
# loading transactions_121000.ttl
# loading transactions_122000.ttl
# loading transactions_123000.ttl
# loading transactions_124000.ttl
# loading transactions_125000.ttl
# loading transactions_126000.ttl
# loading transactions_127000.ttl
# loading transactions_128000.ttl
# loading transactions_129000.ttl
# loading transactions_13000.ttl
# loading transactions_130000.ttl
# loading transactions_131000.ttl
# loading transactions_132000.ttl
# loading transactions_133000.ttl
# loading transactions_134000.ttl
# loading transactions_135000.ttl
# loading transactions_136000.ttl
# loading transactions_137000.ttl
# loading transactions_138000.ttl
# loading transactions_139000.ttl
# loading transactions_14000.ttl
# loading transactions_140000.ttl
# loading transactions_141000.ttl
# loading transactions_142000.ttl
# loading transactions_143000.ttl
# loading transactions_144000.ttl
# loading transactions_145000.ttl
# loading transactions_146000.ttl
# loading transactions_147000.ttl
# loading transactions_148000.ttl
# loading transactions_149000.ttl
# loading transactions_15000.ttl
# loading transactions_150000.ttl
# loading transactions_151000.ttl
# loading transactions_152000.ttl
# loading transactions_153000.ttl
# loading transactions_154000.ttl
# loading transactions_155000.ttl
# loading transactions_156000.ttl
# loading transactions_157000.ttl
# loading transactions_158000.ttl
# loading transactions_159000.ttl
# loading transactions_16000.ttl
# loading transactions_160000.ttl
# loading transactions_161000.ttl
# loading transactions_162000.ttl
# loading transactions_163000.ttl
# loading transactions_164000.ttl
# loading transactions_165000.ttl
# loading transactions_166000.ttl
# loading transactions_167000.ttl
# loading transactions_168000.ttl
# loading transactions_169000.ttl
# loading transactions_17000.ttl
# loading transactions_170000.ttl
# loading transactions_171000.ttl
# loading transactions_172000.ttl
# loading transactions_173000.ttl
# loading transactions_174000.ttl
# loading transactions_175000.ttl
# loading transactions_176000.ttl
# loading transactions_177000.ttl
# loading transactions_178000.ttl
# loading transactions_179000.ttl
# loading transactions_18000.ttl
# loading transactions_180000.ttl
# loading transactions_181000.ttl
# loading transactions_182000.ttl
# loading transactions_183000.ttl
# loading transactions_184000.ttl
# loading transactions_185000.ttl
# loading transactions_186000.ttl
# loading transactions_187000.ttl
# loading transactions_188000.ttl
# loading transactions_189000.ttl
# loading transactions_19000.ttl
# loading transactions_190000.ttl
# loading transactions_191000.ttl
# loading transactions_192000.ttl
# loading transactions_193000.ttl
# loading transactions_194000.ttl
# loading transactions_195000.ttl
# loading transactions_196000.ttl
# loading transactions_197000.ttl
# loading transactions_198000.ttl
# loading transactions_199000.ttl
# loading transactions_2000.ttl
# loading transactions_20000.ttl
# loading transactions_200000.ttl
# loading transactions_201000.ttl
# loading transactions_202000.ttl
# loading transactions_203000.ttl
# loading transactions_204000.ttl
# loading transactions_205000.ttl
# loading transactions_206000.ttl
# loading transactions_207000.ttl
# loading transactions_208000.ttl
# loading transactions_209000.ttl
# loading transactions_21000.ttl
# loading transactions_210000.ttl
# loading transactions_211000.ttl
# loading transactions_212000.ttl
# loading transactions_213000.ttl
# loading transactions_214000.ttl
# loading transactions_215000.ttl
# loading transactions_216000.ttl
# loading transactions_217000.ttl
# loading transactions_218000.ttl
# loading transactions_219000.ttl
# loading transactions_22000.ttl
# loading transactions_220000.ttl
# loading transactions_221000.ttl
# loading transactions_222000.ttl
# loading transactions_223000.ttl
# loading transactions_224000.ttl
# loading transactions_225000.ttl
# loading transactions_226000.ttl
# loading transactions_227000.ttl
# loading transactions_228000.ttl
# loading transactions_229000.ttl
# loading transactions_23000.ttl
# loading transactions_230000.ttl
# loading transactions_231000.ttl
# loading transactions_232000.ttl
# loading transactions_233000.ttl
# loading transactions_234000.ttl
# loading transactions_235000.ttl
# loading transactions_236000.ttl
# loading transactions_237000.ttl
# loading transactions_238000.ttl
# loading transactions_239000.ttl
# loading transactions_24000.ttl
# loading transactions_240000.ttl
# loading transactions_241000.ttl
# loading transactions_242000.ttl
# loading transactions_243000.ttl
# loading transactions_244000.ttl
# loading transactions_245000.ttl
# loading transactions_246000.ttl
# loading transactions_247000.ttl
# loading transactions_248000.ttl
# loading transactions_249000.ttl
# loading transactions_25000.ttl
# loading transactions_250000.ttl
# loading transactions_251000.ttl
# loading transactions_252000.ttl
# loading transactions_253000.ttl
# loading transactions_254000.ttl
# loading transactions_255000.ttl
# loading transactions_256000.ttl
# loading transactions_257000.ttl
# loading transactions_258000.ttl
# loading transactions_259000.ttl
# loading transactions_26000.ttl
# loading transactions_260000.ttl
# loading transactions_261000.ttl
# loading transactions_262000.ttl
# loading transactions_263000.ttl
# loading transactions_264000.ttl
# loading transactions_265000.ttl
# loading transactions_266000.ttl
# loading transactions_267000.ttl
# loading transactions_268000.ttl
# loading transactions_269000.ttl
# loading transactions_27000.ttl
# loading transactions_270000.ttl
# loading transactions_271000.ttl
# loading transactions_272000.ttl
# loading transactions_273000.ttl
# loading transactions_274000.ttl
# loading transactions_275000.ttl
# loading transactions_276000.ttl
# loading transactions_277000.ttl
# loading transactions_278000.ttl
# loading transactions_279000.ttl
# loading transactions_28000.ttl
# loading transactions_280000.ttl
# loading transactions_281000.ttl
# loading transactions_282000.ttl
# loading transactions_283000.ttl
# loading transactions_284000.ttl
# loading transactions_285000.ttl
# loading transactions_286000.ttl
# loading transactions_29000.ttl
# loading transactions_3000.ttl
# loading transactions_30000.ttl
# loading transactions_31000.ttl
# loading transactions_32000.ttl
# loading transactions_33000.ttl
# loading transactions_34000.ttl
# loading transactions_35000.ttl
# loading transactions_36000.ttl
# loading transactions_37000.ttl
# loading transactions_38000.ttl
# loading transactions_39000.ttl
# loading transactions_4000.ttl
# loading transactions_40000.ttl
# loading transactions_41000.ttl
# loading transactions_42000.ttl
# loading transactions_43000.ttl
# loading transactions_44000.ttl
# loading transactions_45000.ttl
# loading transactions_46000.ttl
# loading transactions_47000.ttl
# loading transactions_48000.ttl
# loading transactions_49000.ttl
# loading transactions_5000.ttl
# loading transactions_50000.ttl
# loading transactions_51000.ttl
# loading transactions_52000.ttl
# loading transactions_53000.ttl
# loading transactions_54000.ttl
# loading transactions_55000.ttl
# loading transactions_56000.ttl
# loading transactions_57000.ttl
# loading transactions_58000.ttl
# loading transactions_59000.ttl
# loading transactions_6000.ttl
# loading transactions_60000.ttl
# loading transactions_61000.ttl
# loading transactions_62000.ttl
# loading transactions_63000.ttl
# loading transactions_64000.ttl
# loading transactions_65000.ttl
# loading transactions_66000.ttl
# loading transactions_67000.ttl
# loading transactions_68000.ttl
# loading transactions_69000.ttl
# loading transactions_7000.ttl
# loading transactions_70000.ttl
# loading transactions_71000.ttl
# loading transactions_72000.ttl
# loading transactions_73000.ttl
# loading transactions_74000.ttl
# loading transactions_75000.ttl
# loading transactions_76000.ttl
# loading transactions_77000.ttl
# loading transactions_78000.ttl
# loading transactions_79000.ttl
# loading transactions_8000.ttl
# loading transactions_80000.ttl
# loading transactions_81000.ttl
# loading transactions_82000.ttl
# loading transactions_83000.ttl
# loading transactions_84000.ttl
# loading transactions_85000.ttl
# loading transactions_86000.ttl
# loading transactions_87000.ttl
# loading transactions_88000.ttl
# loading transactions_89000.ttl
# loading transactions_9000.ttl
# loading transactions_90000.ttl
# loading transactions_91000.ttl
# loading transactions_92000.ttl
# loading transactions_93000.ttl
# loading transactions_94000.ttl
# loading transactions_95000.ttl
# loading transactions_96000.ttl
# loading transactions_97000.ttl
# loading transactions_98000.ttl
# loading transactions_99000.ttl

# %%
with driver.session() as s:
    res = s.run("""
        CALL n10s.rdf.import.fetch(
          "file:///import/transactions_88000.ttl", "Turtle",
          { handleVocabUris:"SHORTEN" })
    """)
    print(res.data())
# Out:
# [{'terminationStatus': 'KO', 'triplesLoaded': 0, 'triplesParsed': 0, 'namespaces': None, 'extraInfo': "The following constraint is required for importing RDF. Please run 'CREATE CONSTRAINT n10s_unique_uri FOR (r:Resource) REQUIRE r.uri IS UNIQUE' and try again.", 'callParams': None}]

# %%
for fp in sorted(export_dir.glob("*.ttl")):
    url = f"file:///import/{fp.name}"
    with driver.session(database="neo4j") as s:
        summary = s.run("""
            CALL n10s.rdf.import.fetch(
              $url,'Turtle',{ handleVocabUris:'SHORTEN', batchSize:10000 })
        """, url=url).single()
        print(fp.name, summary["triplesLoaded"])
# Out:
# households.ttl 5607
# products.ttl 567562
# schema.ttl 10
# transactions_0.ttl 53656
# transactions_10000.ttl 54172
# transactions_20000.ttl 53984
# transactions_30000.ttl 54264
# transactions_40000.ttl 54304
# transactions_50000.ttl 54432
# transactions_60000.ttl 54764
# transactions_70000.ttl 54288
# transactions_80000.ttl 54460
# transactions_90000.ttl 54356
